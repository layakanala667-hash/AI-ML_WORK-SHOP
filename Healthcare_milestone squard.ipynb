# %%
# ===================== DDL (Data Definition Language) =====================
# Create hospital database tables (done once during system setup)
"""
CREATE TABLE patients (
    patient_id INT,
    name TEXT,
    disease TEXT
);
"""

# ===================== DML (Data Manipulation Language) =====================
# Insert live patient data into database
"""
INSERT INTO patients VALUES (1, 'Ravi', 'Fever');
"""

# ===================== FIFO (First In First Out) =====================
# OPD / Lab patient queue – first patient treated first
from queue import Queue
patient_queue = Queue()
patient_queue.put("Patient_1")   # First registered
patient_queue.put("Patient_2")

# ===================== Multithreading =====================
# Real-time patient vitals monitoring runs in parallel
import threading

def monitor_vitals():
    print("Monitoring patient vitals")

threading.Thread(target=monitor_vitals).start()

# ===================== LIFO (Last In First Out) =====================
# Latest vitals given highest priority
vitals_stack = []
vitals_stack.append("BP: 120/80")
vitals_stack.append("BP: 150/100")   # Latest reading
latest_vital = vitals_stack.pop()    # Doctor checks this first
# Out:
# Monitoring patient vitals
